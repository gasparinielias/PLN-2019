# %% [markdown]
# # Custom vectorizer

# %%
import os
os.chdir('..')
print(os.getcwd())
# Out:
# /home/mono/materias/pln/repo

# %%
import re
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
import pickle

# %%
from sentiment.tass import InterTASSReader

# Train data
reader = InterTASSReader('corpus/InterTASS/PE/intertass-PE-train-tagged.xml')
tweets = list(reader.tweets())  # iterador sobre los tweets
X = list(reader.X())  # iterador sobre los contenidos de los tweets
y = list(reader.y())  # iterador sobre las polaridades de los tweets

# Development data
reader = InterTASSReader('corpus/InterTASS/PE/intertass-PE-development-tagged.xml')
tweets = list(reader.tweets())  # iterador sobre los tweets
X_dev = list(reader.X())  # iterador sobre los contenidos de los tweets
y_dev = list(reader.y())  # iterador sobre las polaridades de los tweets

# %%
# find tweet with string
for i, x in enumerate(X):
    if 'no' in x:
        break

print(i)
print(X[i])
# Out:
# 0
# Sin ser fan de Juan Gabriel, siempre supe que era una fuerza de la naturaleza. Hoy escuché "Querida", y me dio una ternura enorme.

# %% [markdown]
# ### CountVectorizer as is

# %%
vect = CountVectorizer()
print(vect.fit_transform(X))
# Out:
#   (0, 1408)	1
#   (0, 4049)	1
#   (0, 1204)	1
#   (0, 2551)	1
#   (0, 3412)	1
#   (0, 1482)	1
#   (0, 1967)	1
#   (0, 2760)	1
#   (0, 2237)	1
#   (0, 1735)	1
#   (0, 4194)	2
#   (0, 1452)	1
#   (0, 3386)	1
#   (0, 3943)	1
#   (0, 3783)	1
#   (0, 1754)	1
#   (0, 2183)	1
#   (0, 1046)	2
#   (0, 1616)	1
#   (0, 3750)	1
#   (0, 3812)	1
#   (1, 172)	1
#   (1, 4295)	1
#   (1, 4371)	1
#   (1, 4084)	1
#   :	:
#   (997, 2855)	1
#   (997, 4042)	1
#   (997, 2926)	1
#   (997, 867)	1
#   (997, 2399)	1
#   (997, 4089)	1
#   (997, 657)	1
#   (997, 818)	1
#   (997, 2551)	1
#   (997, 3386)	1
#   (998, 1790)	1
#   (998, 1788)	1
#   (998, 4210)	1
#   (998, 2774)	1
#   (998, 1435)	1
#   (998, 175)	1
#   (998, 2237)	1
#   (999, 968)	1
#   (999, 1295)	1
#   (999, 3727)	1
#   (999, 3493)	1
#   (999, 2388)	1
#   (999, 2551)	2
#   (999, 3386)	2
#   (999, 1046)	1

# %% [markdown]
# ## Changing tokenizer

# %%
vect = CountVectorizer(tokenizer=word_tokenize)
vectorize = vect.build_analyzer()
print(vectorize(X[5]))
# Out:
# ['@', 'fiorela_gue', 'aw', '!', 'recién', 'veo', 'esto', ',', 'sorrry', '!', 'tu', 'pues', 'me', 'dices', 'algo', 'y', 'luego', 'queda', 'en', 'nada', 'vamos', 'hoy', 'a', 'la', 'reu', 'de', 'mi', 'prima', '?', 'le', 'dije', 'a', 'mari']

# %%
def neg_handling_tokenizer(s, max_negations=3):
    neg_words = ['no', 'tampoco', 'ni']
    tokens = word_tokenize(s)
    make_opposite = False
    neg_count = 0
    for i in range(len(tokens)):
        if re.search(r'[.?\-",]+', tokens[i]):
            make_opposite = False
        if make_opposite and \
            tokens[i] not in neg_words and \
            neg_count <= max_negations:

            tokens[i] = 'NOT_' + tokens[i]
            neg_count += 1
        if tokens[i] in neg_words:
            make_opposite = True
            neg_count = 0
    return tokens

def build_tokenizer(max_negations=2):
    return lambda s: neg_handling_tokenizer(s, max_negations)

vect = CountVectorizer(tokenizer=build_tokenizer())
vectorize = vect.build_analyzer()
print(vectorize(X[10]))
# Out:
# ['+saliste', 'ayer', '?', '-no', ',', 'me', 'quedé', 'en', 'casa', '.', '+qué', 'aburrido', 'te', 'has', 'vuelto', '!', '-eso', 'no', 'NOT_dices', 'NOT_cuando', 'NOT_llega', 'la', 'quincena', 'y', 'no', 'NOT_tienes', 'ni', 'NOT_para', 'NOT_el', 'NOT_pasaje', '.']

# %% [markdown]
# ## Changing preprocessor

# %%
def my_preprocessor(doc):
    tagged_users_pat = r'@\w+'
    urls_pat = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\), ]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    vocals_rep_pat = r'(\w)\1{1,}'
    laugh_pat = r'\b[jah]+\b'
    return re.sub(tagged_users_pat, '',
           re.sub(laugh_pat, '<LAUGH>',
           re.sub(urls_pat, '',
           re.sub(vocals_rep_pat, '\g<1>',
           doc.lower()))))

vect = CountVectorizer(preprocessor=my_preprocessor)
vectorize = vect.build_analyzer()
print(vectorize(X[1]))
# Out:
# ['ayer', 'preguntaban', 'dónde', 'están', 'las', 'solteras', 'todo', 'mi', 'grupo', 'alza', 'la', 'mano', 'yo', 'la', 'única', 'que', 'no', 'todas', 'voltean', 'LAUGH', 'verme', 'LAUGH']

# %% [markdown]
# ## Grid-search params finding

# %%
vect = CountVectorizer()
pipe = Pipeline([
    ('vect', vect),
     ('clf', SVC(gamma='auto', probability=True))
])

train_X = [
    'el gato come pescado',
    'la gata come salmon',
    'el gato come salmon'
]
train_Y = [1, 0, 1]

param_dict = {
    'clf__C': [1, 10, 100]
}

cv = GridSearchCV(pipe, param_dict, cv=[[[0, 1], [2]]])
cv.fit(train_X, train_Y)
print(cv.predict_proba(['la gata come', 'la gata come salmon']))
# Out:
# [[0.24483943 0.75516057]
#  [0.20822938 0.79177062]]

# %% [markdown]
# ## Analyzing the models

# %%
with open('models/ES-maxent.model', 'rb') as fp:
    model = pickle.load(fp)
        
y_pred = model.predict(X_dev)

from sentiment.analysis import print_maxent_features, print_feature_weights_for_item

vect = model._pipeline.named_steps['vect']
clf = model._pipeline.named_steps['clf']
print_maxent_features(vect, clf)
# Out:
# N:
# 	! gracias buena : mejor ([-0.99926348 -0.54140291 -0.50538172 -0.49823128 -0.48591543])
# 	mismo odio ni triste no ([0.47739055 0.60890999 0.65199539 0.80367345 0.97239018])
# NEU:
# 	# gracias hoy ! ? ([-0.55027125 -0.54565408 -0.44861801 -0.39353667 -0.38358295])
# 	NOT_pasa vez casa aunque sido ([0.33468925 0.35213721 0.37396061 0.3906679  0.410102  ])
# NONE:
# 	no ... mal hoy ser ([-0.70112823 -0.49297417 -0.42632923 -0.34505574 -0.34179787])
# 	vídeo jugar alguna semana ? ([0.39499268 0.39759467 0.39960258 0.45413998 0.99736069])
# P:
# 	no triste ? ni odio ([-0.71764461 -0.50168295 -0.42048146 -0.39279131 -0.32097587])
# 	mejor genial buen gracias ! ([0.63658058 0.6450265  0.85123413 0.85493357 1.14742911])

# %%
wrongly_tagged = [(X_dev[i], y_dev[i], y_pred[i]) 
                  for i in range(len(X_dev)) if y_pred[i] != y_dev[i]]
sorted(wrongly_tagged, key=lambda t: -len(t[0]))
# Out:
# [('@Sol_4843 si lo es! pero a mi no me pegó del todo la sentí bien poltergeist, lo cual no quiere decir que sea mala solo que no me "atrapó"',
#   'NEU',
#   'P'),
#  ('Buenos días!!!! mi pensamiento esta mañana al despertar es que si o si tengo que ir a dar un paseo al parque y disfrutar de la naturaleza',
#   'NONE',
#   'P'),
#  ('Vine en bici a un curso de mi chamba en San Isidro. Genial...!! Solo mi pelo ha sufrido estragos. Pensare en algo para q mañana no suceda',
#   'NONE',
#   'P'),
#  ('@adricordva pero y que pasa con "todo lo puedo en cristo que me fortalece" "solo Dios le da batallas a los fuertes" nada de eso? jajajaja',
#   'N',
#   'NONE'),
#  ('En 1990 una amiga quiso ser policía. Sus padres se opusieron xq las mujeres no podían ser oficiales. Luego de 26 años, tenemos GENERALAS.',
#   'NONE',
#   'N'),
#  ('@elmejorerico @silva_alvan @meiermq si los Ramirez dicen q son honrados,becerril q es buen padre,Chacón q sí tiene educ.X q no me crees ?',
#   'NONE',
#   'N'),
#  ('@jakahatt algún dia se mejorarán las leyes en la parte digital para que se pueda denunciar a quienes aprovechan estos medios para difamar',
#   'NEU',
#   'N'),
#  ('Pasan los años pero las resacas siguen siendo un misterio. Ayer tomé ron puro y me he levantado tan pancho, tan fresco. Aquí no pasó nada',
#   'NONE',
#   'N'),
#  ('Yo, la que te reza, la de mil caricias calmas, la que te suspira, la de sueños eternos. Sigo siendo yo, contigo, sin ti, tan tuya sin ti',
#   'NONE',
#   'P'),
#  ('uso filtro si y tu no? soy morena tal vez, la combinación de un moreno y una blanca que dan una sacalagua esa soy gorda tal vez 53 kilos',
#   'NONE',
#   'N'),
#  ('Trato de manejar esa sensación de: "no me soporto a mi misma" de estos ultimos 2 días ¡qué dolor! Es que no soy yo misma. #malditoandres',
#   'NONE',
#   'P'),
#  ('Putamare!!.. El tío gritó el gol en mi oído estando en el metropolitano!!.. Y lo peor es que yo asustado grité como jerma!!.. Quemadazo!',
#   'N',
#   'P'),
#  ('la rompas en el primer año de sozu psdta: y si acabas de mandarnos indirectas por twitter y hablamos por wsp y fb no tengo problemas....',
#   'NONE',
#   'P'),
#  ('Aveces cuando leo sus tuits y no entiendo algo, me dan ganas de preguntarles para entender mejor. Pero soy tímido y me quedo con la duda',
#   'NONE',
#   'N'),
#  ('Te amo demasiado!!! Por tu sensualidad , inocencia y belleza...porque pareces tonta pero sé que no lo eres y xq eres joven @ArianaGrande',
#   'P',
#   'N'),
#  ('La tierra del olvido es una bonita canción, pero cuando la pienso Iquitos sería la tierra olvidada porque seguimos tantos años hasta las',
#   'N',
#   'P'),
#  ('@MuniMiraflores @Munozestuvoz hola, ayer separe una cancha de tenis para hoy a las 10 y al llegar estaba ocupada, la alquilaron 3 veces,',
#   'NONE',
#   'N'),
#  ('@PJimr yo ya pasé todos los gratuitos también. es una maravilla. no he pagado nada. la desconexión forzosa de fin de año creo lo evitará',
#   'P',
#   'N'),
#  ('Quiero ver todos los caps de la nueva temporada de Sherlock right now, pero luego sufriré esperando 3 años más para la próxima temporada',
#   'NONE',
#   'P'),
#  ('Y bueno, desde la chamba y tentado por los olores que vienen de casas vecinas: chancho al palo, pavo al horno, lechon... ¡Me dio hambre!',
#   'NONE',
#   'P'),
#  ('@nashi_awaji claro! Es una trilogía genial aunque depresiva, Pero no se xq ayer cuando dijiste del Kage... tenía una mezcla en mi cabeza',
#   'NEU',
#   'P'),
#  ('A ver cuantos extranjeros consignan direcciones falsas, vayan y arrestenlos, cuando uno viaja a otro país te exigen todo, donde y cuando',
#   'N',
#   'P'),
#  ('Estoy contenta, acabo de ver que los gustos que en algún momento transmití sobre una banda en específica, ha llegado a otra persona más.',
#   'P',
#   'N'),
#  ('Estimada @evaayllon, reciba un cordial saludo, nosotros somos el 1er Centro de Ozonoterapia en el Perú, contamos con muchos tratamientos',
#   'NONE',
#   'N'),
#  ('.....el que confía, el que ayuda, el que ama de corazón. Ser feliz con uno mismo no es tan difícil, no dejes qie los demás te roben eso',
#   'NONE',
#   'N'),
#  ('se suave, no dejes que el mundo te haga duro, no dejes que el dolor te haga odiar, no dejes que la amargura robe tu dulzura.. "PERDONA"',
#   'NONE',
#   'N'),
#  ('@hectorandres8 si, parezco niño que cuando sale a la calle todo quiere, y pues me la paso comiendo (flaco no, en vivo se nota mi panza)',
#   'NEU',
#   'N'),
#  ('_ Dibujas muy bonito, pequeño saltamontes. _ Sí. *se pone a saltar* _ _ Cuando sea grande voy a ir a las artes. _ A Bellas Artes. _ Sí.',
#   'NONE',
#   'N'),
#  ('Yo pensaba que el descanso también iba a ser para el fandom, PERO NO! nosotras nunca descansamos Re100 robado #VideoMTV2016 Niall Horan',
#   'NONE',
#   'P'),
#  ('Al César: @peru21 fue el primero en nuestro país que sacó a la chica en bikini de sus páginas. Ahora sacó el horóscopo. Felicitaciones.',
#   'P',
#   'NONE'),
#  ('Sí, suelo ser indiferente y despistada a varias cosas, personalidades y actitudes, sobretodo las que no me interesan. Vivo con los mios',
#   'NONE',
#   'N'),
#  ('@biebsdere hola! Me gustaría saber como se llama el actor ( el q llega ofrecerle el control a el protagonista "Adam") por FA. Responde!',
#   'NONE',
#   'N'),
#  ('Lo "bueno" de viajar o te dejen por hacerlos;es que sacas linea sobre si,realmente,estas "solo" o no.En este caso,quedo mas que claro.',
#   'NONE',
#   'P'),
#  ('Yo sólo ame, y Di todo d mi..... aunque no soy perfecta, solo tengo un corazón sincero, una mente que te piensa a cada momento. pitufo',
#   'NEU',
#   'N'),
#  ('@aurpcy YX no, él es tema aparte. Sólo me shippeo con jongdae je Y están próximos, creí eran del mismo signo, iba a shippearlos + hard',
#   'NONE',
#   'N'),
#  ('@DianaSanchez_04 igual Diana desearte una feliz navidad espero la pasé muy bien con la familia Dios te dé muchas bendiciones te amamos',
#   'NONE',
#   'P'),
#  ('@Isaa5309 Sabíamos que en la mañana, en el caso de SONE, la mayoría trabaja y eso pero valía la pena al menos fuimos en Lima #TeamSNSD',
#   'NONE',
#   'N'),
#  ('@yogui0076 @Capital967 @camcesar el tiempo promedio para ejercitarse, es de 1hr. Si quieres más tiempo, la alimentación también cambia',
#   'NONE',
#   'N'),
#  ('@LaliaB24 Igual después del 20 se quedan sin chamba esos payasos. Lo único bueno de ese día: no quedará UN SOLO obamista en la Tierra.',
#   'P',
#   'N'),
#  ('¿nunca han soñado que estan apuñalando a alguien y al ver que la sangre brota les provoca más clavarle el cuchillo?,¿no?,¿Soy solo yo?',
#   'N',
#   'NONE'),
#  ('Todo estaba bien con esta idea de salir a correr, hasta que me puse el polo que usaba hace 5 meses, la última vez que entrené y adiós',
#   'NONE',
#   'P'),
#  ('Mario si me dio pena con esta frase: "Se que hoy en dia es muy dificil q una chica se acerque a mi" jajajaja SOLTERA REMIX EN AL AIRE',
#   'N',
#   'P'),
#  ('"Contigo porque me matas y ahora sin ti ya no vivo" -->Tal cual! Te mereces todo lo que has conseguido y conseguirás @AbrahamMateoMus',
#   'N',
#   'NONE'),
#  ('Ahorita estaria en Cañete, luego ica, huacho, Arequipa, cuzco, etc. Tmr es cierto cuando dicen "si el tren pasas, tienes que cogerlo"',
#   'N',
#   'NONE'),
#  ('Estoy a punto de comprarme EL VESTIDO para Año Nuevo, lo malo es que si lo compro los días que faltan me mataré haciendo cardio y abs',
#   'NONE',
#   'N'),
#  ('Mañana voy al estadio me dice un amigo y ganamos, claro le digo aunque Brasil es difícil, no me dice yo gano cuidando carros veste...',
#   'NONE',
#   'NEU'),
#  ('Bueno,gracias a algunos(casi gratis) por confiar su salud en mi(un año más) no se enfermen mucho este año pues, jaja mentira, saludos',
#   'P',
#   'N'),
#  ('Todas creemos ser diferentes para esa persona en especial. La verdad es que quien es diferente es el. Ytb hace que pensemos "conocer"',
#   'NONE',
#   'N'),
#  ('@Hctor23188075 @pcmperu no sé eso espero, y lo mismo que anulen eso de la prescribición de los delitos, no sé si menciona algo de eso',
#   'NONE',
#   'N'),
#  ('No es que me volví "ANTISOCIAL", eso nunca, solo que por respeto a mis criterios y lógicas me volví un "ANTIALGUNASPERSONAS" nada mas',
#   'NONE',
#   'N'),
#  ('Que rico es ir al cine sola. Llorar y cagarte de risa a la vez sin que nadie te critique. Hermoso. Repetiré la misma hazaña más tarde',
#   'P',
#   'N'),
#  ('Estoy arta de que todos digan ay si es bien difícil, ay si es bien sacrificada, ay si tienes que estudiar, ay si se van a la mierda?',
#   'N',
#   'NONE'),
#  ('Y es jvsto en ese preciso instante en el cval le dices a tv papá Qve qvieres ser Dj y al final tome la decicion de mandarte a la mrd',
#   'NONE',
#   'P'),
#  ('Sanguchitos, cafecito calientito y maraton de peliculitas de #Saw... Yo tambien me llamo Perú. Asi o mas tranqui??? Dulce o Truco???',
#   'NONE',
#   'P'),
#  ('Soy la unica que quiere un poco mas a Assereto que a Pesaressi? Ojo, no digo que no quiera a GP pero GA, a él lo quiero un poco mas.',
#   'NEU',
#   'N'),
#  ('Chiste: Había un elefante que se llamaba maíz vino un pollito y se lo comió. ja! Lo sé el chiste no es bueno pero igual te hice reír',
#   'NONE',
#   'N'),
#  ('Ya ni voy a hacer bromas weon porque si yo hubiese leído eso durante la salida de Zayn me hubiese empezado llorado y todo que triste',
#   'NEU',
#   'N'),
#  ('@LuciaLu26 JAJAJA crjo, no lo dije por ti mi primer saliente fue a esa edad y mi mamá nunca lo aceptó por esto que recién entendemos',
#   'NONE',
#   'N'),
#  ('Después de siete largos años vuelvo a pasar navidad junto con mi mamá, mi papá y mi hermana. Todos juntos con una yapita de sobrino.',
#   'NONE',
#   'P'),
#  ('@Fantastiqvs Que pases unas lindas fiestas de fin de año y que el próximo sea mucho mejor para ti y los robots ¡Éxitos en todo Aldo!',
#   'NONE',
#   'P'),
#  ('Me calmo un poco y me voy a comprar por mi cuenta Aunque no tengo ni puta idea a dónde ir, ellos se fueron a donde están las ofertas',
#   'NONE',
#   'N'),
#  ('@ivyjara Sabes qué cuando jugue basket contigo , me senti Feliz , pero en mi cabeza tenia muchas dudas , si tu papá me aceptara o no',
#   'NEU',
#   'P'),
#  ('@Anthromet Nunca dije que el docente no enseña. Lo que me interesa es el alumno aprenda, por ello el docente orienta el aprendizaje.',
#   'NEU',
#   'N'),
#  ('@Dilger_A @Peruchapromedio Buenísimo, porque era hasta 30 soles por 2 horas y 28 minutos (con impuestos) la primera semana de enero.',
#   'NONE',
#   'P'),
#  ('he leído que hay un cd drama de aizawa con mic donde van a una cita o algo así pero no lo encuentro, no jueguen con mis sentimientos',
#   'NONE',
#   'N'),
#  ('People be like "Rojo terruco! Con el terrorismo no se negocia... a menos que se les venda armas, si se les vende armas todo bien ".',
#   'NONE',
#   'P'),
#  ('@DerLanPan soy buen hombre, hincha de SC, tengo 2 entradas a Norte, no soy revendedor ....... lo malo es que no las estoy vendiendo',
#   'NONE',
#   'N'),
#  ('Si es que llego a tener hijos no les pondré nombres difíciles de escribir ni de pronunciar, para que no los molesten como a mí jaja',
#   'NONE',
#   'N'),
#  ('@inksquid43 sí. Se desató una lluvia intensa y me empapó las únicas zapatillas que tenía y ahora ya no puedo salir a comprar comida',
#   'NONE',
#   'N'),
#  ('Ya me olvidé cuál era el canal de youtube donde se podía ver cbt ayer pero espero que lo pasen otra vez TE VEO Y ME PICA VICICONTE',
#   'NONE',
#   'NEU'),
#  ('Uy el trío del masajeo prostatico mutuo se está muy calladito, seguro que estarán botando todo lo relacionado con el jueguico ese.',
#   'NEU',
#   'N'),
#  ('@mariann505 jajajaja dale, hacete la boluda vos jajaja igual a vos nunca se te puede tomar en serio te mando un abrazo desde Perú!',
#   'N',
#   'P'),
#  ('Buenos días tuiterlandia! Y hoy en #lavidamodernadetimmy "me olvide de lavar toda mi ropa" y las formas de llegar tarde al trabajo',
#   'NONE',
#   'P'),
#  ('Me he dado cuenta que soy de emocionarme con cosas pequeñas, si no estuviera en la biblioteca estaría saltando de felicidad #Feliz',
#   'NONE',
#   'P'),
#  ('Todo sacrificio tiene su recompensa Este mes me toco estar apretada de dinero pero todo sea por mi salud Llegaran tiempos mejores',
#   'NEU',
#   'N'),
#  ('Acabo de ver a una chica con un saco precioso, tan bonito que me enamoré. Lo malo es que ese saco a mí no me quedaría como a ella',
#   'NEU',
#   'N'),
#  ('@magnobolivar 1) wordpress es más pro. 2) Yo tengo un blog, pero mis lectoras son más de estilo upsocl y buzzfeed, eso aún se lee',
#   'NEU',
#   'N'),
#  ('Super Junior es un escape a todas las cosas malas que pasan en mi vida, es por eso que al apoyarlos no lo veo como una obligación',
#   'P',
#   'N'),
#  ('@esquinabaja si pues, lo publica en su muro sin tu tag e igual todos tus conocidos verán esa foto. jaja ya fue! o tierra tragame!',
#   'NONE',
#   'P'),
#  ('Yo sería vegana, pero luego pienso en el tremendo pan con chicharrón y camote que me metí el otro día, y no...soy débil, no puedo',
#   'NONE',
#   'N'),
#  ('@JessicaaaFranco yeah! yo lo intente but se veia todo oscuro, luego me dasanimé je...pero estaría bien que todo el fandom lo haga',
#   'NEU',
#   'P'),
#  ('En pocos minutos empieza Combate!! Usa el HT #CbtHastaSiempre y coméntanos que fue lo que más te gusto de tu programa favorito...',
#   'NONE',
#   'P'),
#  ('El huevin respectivo debido al feriado...vao a meter una caminata mas sus chelitas para al menos ver que hay abierto en la calle.',
#   'NONE',
#   'N'),
#  ('Necesito un celular decente y mi chip! oshhh al menos una memoria de 32 otra vez! y el próximo año cuzco otra vez por mis fotos!',
#   'NONE',
#   'P'),
#  ('No, la verdad es que no sé qué haré por el cumpleaños de Yixing. O sea, ¿han visto todo lo que hacen las xingmis? Son muy lindas',
#   'P',
#   'N'),
#  ('@MichelleMarti20 es un amor viste el nuevo ep ¿¿¿ solo he visto el preview del ep de mañana y matan a la amiga de haesoo a pesar',
#   'P',
#   'N'),
#  ('cada vez que cito un tweet se va la ubicación sin tampoco poder ponerla en el momento a uds les pasa? TE VEO Y ME PICA VICICONTE',
#   'NONE',
#   'N'),
#  ("Me he puesto a llorar en plena oficina porque no podía abrir mi bolsa de m&m's y no quería pedir ayuda para no tener que invitar",
#   'NONE',
#   'N'),
#  ('A: Ven aquí... Hey estás fumando! B: Pero todos están fumando A: Sí pero a quien voy a besar, a ellos o a ti? #MeCago #MeEnamore',
#   'NONE',
#   'P'),
#  ('Feliz navidad y un increíble 2017 para toda la familia del voleibol peruano en especial a mis queridos colegas de @ZonaAtaqueCMD',
#   'NONE',
#   'P'),
#  ('Y comenzó el día mas amado y esperado ja ja! "Lunes" a comenzar con los dos pies bien puestos en la tierra. Así que adelante!!.',
#   'N',
#   'P'),
#  ('Cada dia se acerca mas la navidad agamos que todos los niños tengan un motivo x cual sonreir invitalo a tu casa buenos dias!!!!',
#   'NONE',
#   'P'),
#  ('@Kano_8_ Lo mejor para el es que salga del Club Zidane no le da la Oportunidad de Jugar! A mi no me gusta que este en la Banca.',
#   'NEU',
#   'P'),
#  ('Te das cuenta que ya te va a venir la regla porque te estás empezando a poner bipolar y los antojos por comer dulces aumentaron',
#   'NONE',
#   'N'),
#  ('Como van tus vacaciones camilita? , es cierto que estas en cancun ? Porque no subes mas snapchats? ,te extraño @camilacabello97',
#   'NONE',
#   'N'),
#  ('@JordiWild Primero los XV de Ruby ahora Tongo, jaja Giorgio de a pocos vas conociendo Latinoamerica ... aunque no la mejor cara',
#   'NONE',
#   'N'),
#  ('Viendo con mi gordiflaqui LOCA POR LAS COMPRAS y el diciendo se parece un poco a ti o tu a ella jjajajajaja yo no compro tanto',
#   'NONE',
#   'N'),
#  ('@LightAfterRain_ Ya sé, pásame tu número por interno y yo te paso todo por wpp, de paso que tú también me ayudas con NCT y así',
#   'NONE',
#   'N'),
#  ('@JimenaTagle sí, como pasa el tiempo verdad? se siente nostalgia y a la misma ves una alegría inmensa Gracias @JimenaTagle !!!',
#   'NEU',
#   'P'),
#  ('Esos primeros puestos para Nadine, Alan y Keiko están bien ganados, más bien creo que Ollanta debería estar más abajo. @Imapax',
#   'NEU',
#   'N'),
#  ('@BTS_twt yo lo estoy viendo ahora..porque tengo que esperar los subtitulos! ️ pero vale la peno...todo sea por el hermoso de V',
#   'NONE',
#   'P'),
#  ('Y hoy, que salir de la cama era lo último que quería hacer, nos fuimos de paseo a La Punta valió la pena no quedarse en casa!',
#   'P',
#   'N'),
#  ('Ouch!! ese momento incomodo cuando te preguntan que le viste? ó, no se porque estuviste con el? .... El aspecto no lo es todo',
#   'NEU',
#   'P'),
#  ('Mejor me regreso a lee el manga, me cuesta mantenerme optimista justo ahora y tengo ganas de hacer drama. #YAsíaNadieLeAgrado',
#   'NONE',
#   'P'),
#  ('@AlejVillalobos @mczorro No es perfecta, tiene sus cositas. Pero el balance es bueno, bastante bueno. Y claro, sales cantando',
#   'P',
#   'N'),
#  ('Les personas no somos eternas Lo más importante es el legado que dejamos, la enseñanza para toda una familia y una generación',
#   'NEU',
#   'N'),
#  ('Vos enamorate a tu mejor amiga sin que ella lo sepa pero el dia que vos lo sepa o se lo diga como ella lo tomara .... Rzpsta',
#   'NONE',
#   'P'),
#  ('—¿A dónde vas tan maquillada? —A una fiesta, mamá. —¿Eres el payaso? —¡MAMÁAAA! —JAJAJÁ, cállate y hazme reír o no vas. —Ok.',
#   'NONE',
#   'N'),
#  ('Me he guardado desde el jueves para salir hoy... y mi mejor amiga me dice: me vino la regla, no la hago. La odio por perra!',
#   'N',
#   'P'),
#  ('@AndresWieseR cuerito!! Que lo hayas pasado súper grandioso!!! Felices 33, debemos cuidarte más este año!! Edad de cristo!!',
#   'NONE',
#   'P'),
#  ('escucho una canción romántica, de esas que serían hermosas dedicar, pero no hay nadie en quién pensar Nadie me gusta carajo',
#   'NONE',
#   'N'),
#  ('Manolo: se llama H&M por Hombre y Mujer. Yo: ..pero.es una marca americana, no tendría sentido. Manolo: callate butch. Yo:',
#   'NONE',
#   'N'),
#  ('@Slayer_X @hdanniel hoy juega el Liverpool con el City (y también son las semifinales del futbol americano universitario)',
#   'NONE',
#   'P'),
#  ('@ElohaLing Ayyy, no debí haber tuiteado esto. Olvidé que estabas por acá, no me odies ( Hablo en serio, no es sarcasmo )',
#   'NEU',
#   'N'),
#  ('#DalasCastigos No atendia en clase y la profesora para castigarme me mandaba a trabajar en el campo... maldita profesora',
#   'NONE',
#   'N'),
#  ('@Lizzfrr el nuevo Dr Vet @fernandomerino ayudeme mi perrita no acepta a un cachorro que le hemos dado temporal que hago?',
#   'NONE',
#   'N'),
#  ('pásala bien con todos tus seres que el amor y la paz llene tu hogar con tus seres queridos y muchos éxitos en todo ¡!!!',
#   'NONE',
#   'P'),
#  ('Entró una venezolana a trabajar en la empresa donde laboro. Me apena la crisis en su país, está bien jodido todo allá.',
#   'N',
#   'P'),
#  ('Me gusta mucho ir a Chepén y estar con la familia de Kike. Lo que no me gusta es tener que trabajar el lunes siguiente',
#   'NEU',
#   'N'),
#  ('Mi jefe me acaba de regañar por un error que él cometió Al medio del regaño recordó que era su culpa y cambio de tema.',
#   'NONE',
#   'N'),
#  ('A veces me gustaría que a novia le gustara Disney tanto como a mi. Salen nuevas pelis o avances y necesito fangirlear',
#   'NEU',
#   'N'),
#  ('#2añosdelegiónholk Un año antes no me imagine , que un grupo(El mejor) sea mas importante que muchas cosas en mi vida',
#   'NONE',
#   'P'),
#  ('Feliz Cumpleaños @unforesto ! Te deseo los mayores éxitos muchacho! . @YurikitoKSP un par de chelas heladas parfavar!',
#   'NONE',
#   'P'),
#  ('@LoboDeAndunie que buena, esos alucinados que fingen ser Lobos, y esos que fingen ser gay y no saben nada de nosotros',
#   'NONE',
#   'N'),
#  ('Buen día.... Para delante una nueva semana con fe...!!!! Con fe ... Cuanto tiempo me aguantas con mi forma de ser...',
#   'NONE',
#   'P'),
#  ('@JEESrcismo por eso mismo. Yo no veo la diferencia en una supuesta "vida sana" impulsada por el veganismo y el resto',
#   'NONE',
#   'N'),
#  ('#2AñosDeLegiónHolk Llevo como unos 8 meses Talvez menos o mas no sé Me enseñaron y demostraron que LH es algo magico',
#   'P',
#   'N'),
#  ('@Quillaquiroz y, según yo, miradas a los ojos que valen por mil (todo de manera independiente a la sustancia "amor")',
#   'NONE',
#   'P'),
#  ('@Phoemi Hola! en estos momento van chequear tu solicitud para poder ayudarte lo antes posible, lamentamos el retraso',
#   'NONE',
#   'P'),
#  ('@JayroCerasuolo oh no te la debo negrito, lo lamento, prometo ir al próximo kaos ir desde las 8 pm y guardarte cola',
#   'NONE',
#   'N'),
#  ('@arremar ke paso????? Xq yano saldran dspues del noticiero 24 horas xqqqqqqqq!!!!!!!!!! Nadie nos da una elicacion',
#   'NONE',
#   'P'),
#  ('Con entusiasmo y optimismo en este primer día del año. Todo depende de lo que Dios me tiene preparado. #VamosConFe',
#   'NONE',
#   'P'),
#  ('@Alexander_Isai0 pKAJAJAJJ yo me siento algo quemado y se mee anda pelando la nariz ahr por no ponerse bloqueador',
#   'NONE',
#   'N'),
#  ('Al callejerito Hércules le han medio destrozado el ojo derecho Ptm!!! Quien ha sido!!! Maldición, quiero matar!!!',
#   'N',
#   'P'),
#  ('@jbendezu Hola Javier. Te escribimos la vez pasada indicando que será en la conferencia anual de Los Productores.',
#   'NONE',
#   'N'),
#  ('Bueno, ¡a finalizar el último libro que tengo en mi “currently-reading” de @goodreads antes que termine el año!',
#   'NONE',
#   'P'),
#  ('@JesusEduardoG @xeilachvr @YouTube vi ese video hace un tiempo me pareció chevere . Pero no me gusta la canción',
#   'NEU',
#   'N'),
#  ('Ahora queda esperar a que se estrene en nuestra cartelera las últimas películas voceadas para los premios Oscar',
#   'NONE',
#   'N'),
#  ('No entiendo la actitud agresiva gratén de tuiter. Si te jode lo que digo no masoquees y no me sigas. Es lo sano',
#   'NEU',
#   'N'),
#  ('Estoy en esa delgada línea entre jugar un duelo de cartas Yu gi oh en playstation o planchar mi ropa de mañana',
#   'NONE',
#   'N'),
#  ('@fioyaz Es que tu tuit me recordó a un diálogo de una serie muy graciosa que yo veía seguido antes. Pero no es',
#   'NONE',
#   'N'),
#  ('Adios pajita jajajaja #ReproducePonteBonitaByMHart #VillaranCoimera #SIGUEMEYTESIGO #SiguemeYTeSigoAlInstante…',
#   'NONE',
#   'P'),
#  ('Ser feliz si eso significa alejarte de personas que quieres pero que te hicieron daño importa mas tu felicidad',
#   'NEU',
#   'P'),
#  ('Hoy es Domingo, hoy es domingo, hoy hoy es domingo, domingo es, si es domingo, ya para no olvidarse buen día',
#   'NONE',
#   'P'),
#  ('Ojalá que al chico de lado, que acaba de salir de una entrevista, lo llamen sería un buen regalo de Navidad',
#   'NEU',
#   'P'),
#  ('@ChenteOink jajajaja este es un plato del restauran de mi casa, cuando quieras tienes tu descuento familiar',
#   'NONE',
#   'N'),
#  ('@BeluFerruzo si o si regresaras a Perú baby! Es más, cuando leas esto es probable que estés aquí ya #PorFin',
#   'NONE',
#   'P'),
#  ('"Si tu supieras que por ti me muero, que yo te quiero te quiero te quiero te quiero..." POR FIN TE ENCONTRE',
#   'NONE',
#   'P'),
#  ('@JessicaSolano veras que no es nada grave, mejor ahora que le hagan todo... yo también por San Miguel sola',
#   'P',
#   'N'),
#  ('@Joe_Padisha_Mon @DiarioDeCurwen Estaba en otro horario pero yo no podía ir. Claro, como mejor te acomode.',
#   'NONE',
#   'N'),
#  ('que rico es salir a esta hora del trabajo más tiempo para escuchar @RadiomarPlusFM y a mi @Nandocabanillas',
#   'P',
#   'N'),
#  ('Que seriedad pues papá!! A ver el cabello con TINTE? Me da bien? MEJOR PREFIERO NATURAL! Así me identifico',
#   'N',
#   'P'),
#  ('@Lupalma12 por favor, mis innumerables tweets a las 3,4,5 de la mañana hablando webadas avalan mi reinado',
#   'NEU',
#   'N'),
#  ('@JesusAlzamora No yo no lo senti pero dicen que fue de 4... lo bueno es que siempre hay que estar atentos',
#   'NONE',
#   'N'),
#  ('@TubinoCarlos te vas de la "Bankada"? Que buena noticia... Pero ahora seguro la china te da por el tubino',
#   'P',
#   'NONE'),
#  ('Un poquito amarga mama #UnaSemanaDel2017YYo #felizdiadereyes #OTConcierto #HablaVillaran #SIGUEMEYTESIGO',
#   'N',
#   'P'),
#  ('@BrSC8 @Migvelinho puta que rico csm. Vuelvo al encierro y de paso a comer carnes congeladas por 15 días',
#   'P',
#   'N'),
#  ('Ya pasó una semana de estar en Camaná y parece que hubiera llegado ayer recién, que rápido se pasa todo',
#   'NONE',
#   'N'),
#  ('Ayeeer en Sasuke Shinden! JAJAJA que letra mas fea debe ser de naruto. Por otro lado la policía militar',
#   'N',
#   'P'),
#  ('@ysitedigoalgo Como la mayoría de los mortales  . Por lo menos es lindo por dentro y se acepta como es.',
#   'P',
#   'N'),
#  ('RIP Dean "pestañas perfectas" Winchester. Ya sé que va a regresar en el siguiente capítulo, pero igual',
#   'NONE',
#   'N'),
#  ('#HolaATodos @rafaelcardozotv Necio!!!!!! Abre tu cerebro porfavor!!! No es la palabra, es el contexto',
#   'N',
#   'P'),
#  ('Por cada detonación de pirotéxnicos a mi Morita parece darle un infarto ¡Terminen de una vez con eso!',
#   'NONE',
#   'P'),
#  ('Ese aplauso para Diego Luna y Felicity Jones fue estruendoso. Tengo ganas de ver Rogue One y no puedo',
#   'P',
#   'N'),
#  ('@Libranorte te entiendo, toda mi vida me he sentido igual; pero siempre hay que ser fiel a uno mismo',
#   'NEU',
#   'N'),
#  ('Aprovecharé que no hay nadie en mi casa para subir el volumen lo más alto, gritar a pulmón, y bailar',
#   'NONE',
#   'N'),
#  ('Siempre me tengo que enamorar de alguien en el micro y cuando me bajo, despedirme es lo más doloroso',
#   'NONE',
#   'N'),
#  ('@atenea2guerrera @JorgePonceCaraz siii !! eso haré !! yo no ubico esa publicación alucina ! que raro',
#   'NONE',
#   'N'),
#  ('Bajar mucho de peso y no sentirse contenta. Será porque no fue a base de ejercicios. Un mes y quedé',
#   'NEU',
#   'N'),
#  ('5 días seguidos en el cine, un día de descanso para ver a mis perritas y luego otro día más de cine',
#   'NONE',
#   'P'),
#  ('Pasajes Maleta Mis 3 potes de bronceador Alguien está emocionada, excepto por dejar a Salem solito',
#   'NEU',
#   'N'),
#  ('Está dicho!..mi vida es una gran aventura, lleno de emociones, decepciones, ilusiones, sonrisas,',
#   'NEU',
#   'P'),
#  ('@ivyjara No te cambiaria , ni por la mujer más bella del mundo , Porqué Solo tengo ojos para ti ',
#   'P',
#   'N'),
#  ('Vamos Ame vamos....bahhh.....q mas da.....conence el año cansada..... quiero solo dormir hoy....',
#   'NONE',
#   'N'),
#  ('Toca ir a trabajar así me duela el tobillo, necesito el dinero ya que ahora es mi único ingreso.',
#   'NONE',
#   'P'),
#  ('@Gadhafy a mi me renovaron y no me tocaron (hasta ahora) el sueldo así que ando más o menos easy',
#   'P',
#   'N'),
#  ('@BtzabGomez alaaaaaaaaa jajaja yo tengo aire acondicionado al menos en donde estas trabajando??',
#   'NONE',
#   'N'),
#  ('Necesito un te canela en serio no se si llorar o estar alegre o no se que me siento desubicado',
#   'NEU',
#   'N'),
#  ('#2AñosDeLegiónHolk No importa que seas "niu" o "old" Si amas a LH , eres bienvenido a mi casa',
#   'P',
#   'N'),
#  ('¡Chica / chico material!! Que la salud y el dinero NUNCA falten este nuevo año #Feliz2017 \\o/',
#   'NONE',
#   'P'),
#  ('Bueno Bueno Nuevo año Espero q este año sea mejor q el anterior Y comenzare con ultra drivers',
#   'NONE',
#   'P'),
#  ('"Yo les deseo que sus deseos sean tan fuertes, que se conviertan en voluntad..." Feliz 2017!',
#   'NONE',
#   'P'),
#  ('Buen año nuevo gracias.... @alesalazarm @marielaslazar @romi_rb5 @AnikaJohana #conlasmejores',
#   'NONE',
#   'P'),
#  ('La primera melancolía del año Ojalá la oportunidad regrese y el talento esté ahí siempre u.u',
#   'NONE',
#   'P'),
#  ('Tres cosas para lo que no soy buena: 1- cocinar 2- maquillaje 3- cantar. Pero así me quieren',
#   'NEU',
#   'N'),
#  ('Creo que mi papá se ha enojado porque le dije que pasaría Año Nuevo con mi mamá y no con él',
#   'NONE',
#   'N'),
#  ('Recibir el año nuevo sin luz, que sean las 10 y sigamos sin luz #micelmuere #notengobateria',
#   'N',
#   'P'),
#  ('Cuando sales a comer solo #sunglasses #blackandwhite #bn #mall @ Real Plaza - Centro Civico',
#   'NONE',
#   'N'),
#  ('@Terafobia buenos días princesa Era inevitable, tenía que decir esa frase de #lavidaesbella',
#   'NONE',
#   'P'),
#  ('@zophiap vaya manera de despedir este año... pero en otros lugares su bienvenida fue fatal',
#   'NONE',
#   'N'),
#  ('@danidiazcordova @Silvia_Dg pero que mejor se dedique a salud pública ella es mi esperanza',
#   'NEU',
#   'N'),
#  ('@ivyjara Aunque te extraño mucho y quisiera abrazarte y besarte con todo mi amor y cariño',
#   'NONE',
#   'P'),
#  ('@EstefaniaM siempre habrá algo amiga, pero con el tiempo lo superas y pierden importancia',
#   'P',
#   'N'),
#  ('@VictorinoSv yo amenecí mal y estaba en el hospital u.u pero ya estoy regresando a casa.',
#   'NONE',
#   'N'),
#  ('Hay dos personas a las que les confío todo y justo en este momento, ni en visto me dejan',
#   'NONE',
#   'N'),
#  ('@Florinm2709 Si no eres una mala influencia, fracasaste como mejor amiga. gracias amiga',
#   'NONE',
#   'P'),
#  ('@ccori_alejandra y yo te extraño un mundo! este verano sin ti destruye mi alma #dramaon',
#   'N',
#   'P'),
#  ('@Angiecava1995 Jajaja nooo, lo digo porque me parece raro ... Sigo sin ánimos de beber',
#   'NONE',
#   'N'),
#  ('@mariagraciav gracias! y aun no se que dia pero creo que el 12/13 estare libre en Lima',
#   'NONE',
#   'P'),
#  ('mi última noche en tarapoto la he pasado hermoso estos días y en verdad no quiero irme',
#   'P',
#   'N'),
#  ('Totoro casi listo #Imelda #torta #totoro #cake #designcake #pastelería #lima #diseño…',
#   'NONE',
#   'N'),
#  ('Cusco, la luna y yo, recibimos com los brazos abiertos al primer día del 2017 #cusco…',
#   'NONE',
#   'P'),
#  ('!! Yo solía amarla,Yo sabía que la echaría de menos !! #GNR   Empezando El Dia Griss',
#   'NONE',
#   'P'),
#  ('Camisetas por comprar la 10 de Tevez con Boca y la nueva de Tomas Rincón con la Juve',
#   'NONE',
#   'P'),
#  ('Desde mañana me dedicaré a estudiar y dejaré mis sentimientos amorosos por otro lado',
#   'NONE',
#   'N'),
#  ('Y bueno, fue un año nuevo diferente. Pero se acabó y ahora toca volver a la realidad',
#   'NEU',
#   'P'),
#  ('Hoy toca cocina ¿Qué es mas rico chicharrón o ceviche de pota ??? @ Muelle Fesa ex…',
#   'NONE',
#   'P'),
#  ('Escuchando soundtracks antiguos... primero en nostalgia y ahora caigo en depresión.',
#   'N',
#   'P'),
#  ('@LuchoCastanedaL prohibir paraderos En Pza Union, Pza 2 Mayo agilizaria el tráfico.',
#   'NEU',
#   'N'),
#  ('@natsumifs Buena Nats ! Yo llevo casi año y medio sin fumar y fue la mejor decisión',
#   'NONE',
#   'P'),
#  ('Me preguntó mi nombre!!! Mi último día e interactúo con Samuel! Vaya suerte la mía',
#   'N',
#   'P'),
#  ('@VaneCastilloP No creo que tanto, ah. Lo que sí, es que será mucho más placentero.',
#   'P',
#   'N'),
#  ('Me he en encontrado como 8761653729751528763 Colombianos entre Lima y Nasca, Perú.',
#   'NONE',
#   'N'),
#  ('a mí me dicen ven a mi casa a las 2 y lo multiplico por 4, nos vemos a las 8, papu',
#   'NONE',
#   'N'),
#  ('Si pudiese cantar bonito no dejaría de hacerlo con "Come what may" de Moulin Rouge',
#   'NONE',
#   'P'),
#  ('@CheLa_is Marcelitaaa, aprovecha nuestro hermoso clima. No sabes cuánto se extraña',
#   'P',
#   'N'),
#  ('Maldito maduro mil veces, por su culpa tuve que salir del país y alejarme de ella',
#   'N',
#   'P'),
#  ('Fabiola dijo que le pida trabajo a su papa en su constructora , uhmm era que vaya',
#   'NONE',
#   'N'),
#  ('@LeslieLeiblinZa claro que si, yo estoy en Asia se sintió fuerte pero fue cortito',
#   'NONE',
#   'NEU'),
#  ('@fferxx_ yo te extraño más con suerte a fines de febrero voy por eeuu y te visito',
#   'NONE',
#   'N'),
#  ('@SSLopezCano Es recíproco. Y eso que casi nos cae @enanagorda. La que se armaba.',
#   'NEU',
#   'N'),
#  ('Lo que decidas hacer. Asegúrate que te haga feliz #EsteVeranoDebería #SerIntenso',
#   'NEU',
#   'P'),
#  ('No te tomes la vida tan en serio. Diviértete y has tonterías cada vez que puedas',
#   'NONE',
#   'N'),
#  ('No pude con mi genio y voy a almorzar. Para colmo combinado de pollo con gaseosa',
#   'NONE',
#   'N'),
#  ('@atenea2guerrera maldita sea !!!!! no fui yo Gracias Kellyyyyyyyyy !!!!!!!!!!!!!',
#   'NEU',
#   'P'),
#  ('@AlfonsoEmilioL La próxima vez que no vea lo entrevisto y pregunto que escucha.',
#   'NONE',
#   'N'),
#  ('Reyes magos ; dinero .incienso y mirra para un rey que seria crucificado #Jesus',
#   'NONE',
#   'N'),
#  ('@nat_ea con realidad me refiero al trato limeño, nada comparado con el cusqueño',
#   'NONE',
#   'N'),
#  ('Regresé de la playa hoy y literal todo el día he dormido, y aún sigo con sueño',
#   'NONE',
#   'N'),
#  ('Una de las cosas más maravillosas en mi mundo es salir tarde y llegar a tiempo',
#   'P',
#   'N'),
#  ('@SamanthaLaraC faltabas mi samo, la familia unida jajajajaja, te extraño, venn',
#   'N',
#   'P'),
#  ('@YurikitoKSP @Universitario que feo tu corazoncito! Deja ser feliz a los demás',
#   'NONE',
#   'P'),
#  ('Empezamos con un par de problemillas nooooo pero este año hay que ser más +++',
#   'NEU',
#   'N'),
#  ('!Feliz año nuevo! este 2017 sea realmente un año muy lindo y maravilloso ^_^',
#   'NONE',
#   'P'),
#  ('Aahhh bueno, gracias a todos por sus buenas vibras, sí quede para el trabajo',
#   'NONE',
#   'P'),
#  ('@Elicrema He ahí, el misterio del por qué no llegas a la fase REM, resuelto.',
#   'NONE',
#   'N'),
#  ('Mientras mi jefe no se entere todo ok lol Los demás si tenemos sentido común',
#   'NONE',
#   'N'),
#  ('@ItsCister y tambien feliz año aun q en mi pais aun no lo sea :V pero igual',
#   'NONE',
#   'N'),
#  ('@paunik oh. los mios tampoco, asi que por eso lo veo solo, en la tele vieja',
#   'NONE',
#   'N'),
#  ('@MaricieloCernaU justo ayer que vi tu foto te iba a decir que bonita calle',
#   'P',
#   'N'),
#  ('Mi mamá me acaba de robar mi oso de peluche Pero tengo a mi bello Snorlax',
#   'NONE',
#   'N'),
#  ('Quiero decirte, hola, como estas? Pero... los check azulitos me dan miedo',
#   'NEU',
#   'N'),
#  ('Es inevitable que salga mi lado niño cuando se trata de fútbol y/o carros',
#   'NONE',
#   'N'),
#  ('Vamos a trabajar más en ello No puedo volver a ser una persona flemática',
#   'NEU',
#   'N'),
#  ('3 de enero, fecha mágica, fecha viajera, fecha de hacer sueños realidad',
#   'NONE',
#   'N'),
#  ('Primera reunión del equipo... "¿Qué Tiene Miguel?" Pronto!!!! @ Ginebra',
#   'NONE',
#   'P'),
#  ('Mi celular se cayó horrible y por lo visto se afectó la cámara frontal.',
#   'NONE',
#   'N'),
#  ('Me emociona mucho que les pasen cosas bonitas a las personas que quiero',
#   'P',
#   'N'),
#  ('Cuidando mi cachete derecho para que ne salga un grano en el izquierdo',
#   'NONE',
#   'N'),
#  ('@mayrapierola no todas las personas nena. Yo nunca seré cagada contigo',
#   'NONE',
#   'N'),
#  ('@TatianaAstengoB esa serie se nota muy interesante a verla por Netflix',
#   'P',
#   'N'),
#  ('Solo han pasado 2 horas desde que me levante y ya tengo sueño de nuevo',
#   'NONE',
#   'N'),
#  ('Feliz año! Las mejores vibras y éxitos para este 2017! Cambio y fuera',
#   'NONE',
#   'P'),
#  ('Debo dejar de hacer bromas porque cuando hable en serio no me creerán',
#   'NONE',
#   'N'),
#  ('A un paso de darle una vuelta completa a nuestro sol Lov u @ El Tizón',
#   'NONE',
#   'N'),
#  ('@cinencuentro gracias por compartir el teaser amigos de Cienencuentro',
#   'NONE',
#   'P'),
#  ('@BleuatreMil se muestran solitos, no está difícil la cosa felizmente',
#   'P',
#   'N'),
#  ('@pau_2189 siempre la gente es pesada, pero normal Pau, que te llegue',
#   'NEU',
#   'N'),
#  ('Mis demonios internos me dicen tatuajillos pero mi corona me dice no',
#   'NONE',
#   'N'),
#  ('@ivyjara Me cambiarias Por dinero o Por El chico más guapo del mundo',
#   'NONE',
#   'N'),
#  ('Que bonito debe ser vivir así, siendo caradura y sin pedir disculpas',
#   'N',
#   'P'),
#  ('@RoxyMarquez91 me puedo volver loco yo quiero me MUERO POR UN GATITO',
#   'NONE',
#   'N'),
#  ('@lizdanielalina1 solo rt #QueremosERDLalas930pm no des corazón plis',
#   'NONE',
#   'N'),
#  ('No se que está pasando conmigo ultimamente, pero extraño a toodooos',
#   'NONE',
#   'N'),
#  ('@KarolCavero Hola amiga, hermana de mi buen amigo. Ni para mi tengo',
#   'NONE',
#   'N'),
#  ('@BestiasAlVolant Excelente, siempre me persigno cuando entro a uno',
#   'P',
#   'N'),
#  ('@citayrnde @VickyySquad fui la primera seguidora merezco algo? No?',
#   'NONE',
#   'N'),
#  ('Feliz 2017!!! Cachen más y dejen de ser tan aguantad@s por Tuiter',
#   'NEU',
#   'P'),
#  ('@Efrainpuntocom sígueme por ig por allá estoy más activa que aqui',
#   'NONE',
#   'N'),
#  ('El mejor #piropo de mi vida «estás #buchisapa y pareces un #kion»',
#   'N',
#   'P'),
#  ('Hazme un favor y has lo posible por no cruzarte conmigo este año',
#   'NONE',
#   'N'),
#  ('hola si quieren ver la historia que publico entren aqui gracias',
#   'NONE',
#   'P'),
#  ('Alguien que me regale una ektachrome y una cámara misia antigua',
#   'NONE',
#   'N'),
#  ('Hoy con nuevos retos, ya no falta nada de nada para el GRAN día',
#   'NONE',
#   'P'),
#  ('@mfv7 Ayer la agarré a medias. Aún no veo el episodio completo',
#   'NONE',
#   'N'),
#  ('@kevinghidalgo @BrunnerCesar @Aylen_1616 El prox viernes vamos',
#   'NONE',
#   'N'),
#  ('@Bmndjr no funciona en iOS está desarrollada solo para Android',
#   'NONE',
#   'N'),
#  ('@ludwikapaleta si, muy hermoso, y eso que no me conociste a mi', 'P', 'N'),
#  ('Nunca dejes el fb abierto y tu hermana a lado, es un PELIGRO!', 'N', 'P'),
#  ('A recuperar la resistencia física, hola Viernes sangriento!!!',
#   'NONE',
#   'P'),
#  ('Ya me dio nostalgia viendo tantos videos de clásicos antiguos', 'P', 'N'),
#  ('Sé fiel a ti mismo, nunca es tarde para hacer las cosas bien', 'NEU', 'N'),
#  ('@JohnsitoCb Ya sabía que un chivito se iría a la mariconada.', 'NONE', 'N'),
#  ('Cumplí mi caprichito buena compañía #ceviche #chela #pilsen', 'NONE', 'P'),
#  ('MAPEO DE PROCESOS!!!! PMBOK ya falta poco... Pronto a vente', 'NONE', 'P'),
#  ('Peeeeeero que necesidad hay para que tanto problema. JAJAJA', 'NONE', 'N'),
#  ('Mejor no llamo por teléfono a nadie o los mandaré al carajo', 'NONE', 'N'),
#  ('@joannabolona trankila colorada ya saldra el sol paciencia', 'NONE', 'N'),
#  ('@OxanaJuliana1 estan lindos tus gatitos.- producen ternura', 'P', 'N'),
#  ('#FinDeSemanaPara perderse hasta las últimas con los amigos', 'NONE', 'P'),
#  ('@carlonchodemoda ya pss quiero ver juego , aguita pa ti!!!', 'NONE', 'P'),
#  ('Pasa la noche conmigo bonita y quédate mañana todo el día', 'NEU', 'N'),
#  ('@Victoriaasabo vi hasta el 2do episodio pero te hare caso', 'NONE', 'N'),
#  ('@felibesset @GilmoreGirls esperamos los nuevos capítulos', 'NONE', 'P'),
#  ('¿Alguien de buen corazón que quiera hacerse el desayuno?', 'NONE', 'P'),
#  ('4 de enero y hoy empiezo a disfrutar todo todito todoooo', 'P', 'N'),
#  ('El quinto día #cousins #Holidays @ Previos Restobar-Pub', 'NONE', 'P'),
#  ('El dolor de rodilla no me ha parado desde el primer día', 'NONE', 'N'),
#  ('No tomo alcohol y siento que mi cuerpo esta adormecido', 'NONE', 'N'),
#  ('@JorgeIsique jajajaja feliz año enano cuando vengas ya', 'NONE', 'P'),
#  ('@ninobracho no reniegues y pasa un super inicio de año', 'NONE', 'N'),
#  ('Construye nuevos recuerdos, en eso consiste el futuro', 'NONE', 'P'),
#  ('Traigo un bronceado envidiable. Mentira. Todo me arde', 'NEU', 'N'),
#  ('@vicoba89 la verdad es que estamos buscando full time', 'NONE', 'N'),
#  ('Seré breve: quiero yuquitas y por mi chamba no venden', 'NONE', 'N'),
#  ('Lilo y Stich Somos ohana #Ohana #Familia #LiloyStich', 'NONE', 'P'),
#  ('@gabogarcia Lo pronunciamos pellót así fuerte!! . Cl', 'NONE', 'P'),
#  ('Dios aprieta pero no ahorca, creo que es muy cierto', 'NEU', 'N'),
#  ('@vanessasaba75 Feliz Año Bella! Las mejores vibras', 'NONE', 'P'),
#  ('Feliz de ver a mis amigos felices #BuenaVibraAlFin', 'NONE', 'P'),
#  ('Amigos, me sacaron la mierda hoy pero estoy feliz', 'NEU', 'P'),
#  ('@jibajawo Espero que para ti tbn sea un buen año.', 'NONE', 'P'),
#  ('@lovingmykookie extrañare este tweet como fijado', 'NEU', 'N'),
#  ('@claudiaizaguirr muchas gracias, de igual manera', 'NONE', 'P'),
#  ('Quiero unas verdaderas vacaciones. Las necesito.', 'NONE', 'P'),
#  ('Sólo piensa q diste todo... y duermes tranquila', 'NONE', 'N'),
#  ('La realidad es que ella ya no es mi mejor amiga', 'NONE', 'N'),
#  ('Un nuevo ciclo y con muchas cosas por realizar', 'NONE', 'P'),
#  ('Casi me quedo dormido en el bus hasta Trujillo', 'NONE', 'N'),
#  ('En boca de mentiroso lo cierto se hace dudoso.', 'NONE', 'P'),
#  ('#puraresponde feliz navidad pura pasalo super', 'NONE', 'P'),
#  ('@vanessasaba75 que tengas un lindo jueves ...', 'NONE', 'N'),
#  ('Tantos argentinos y @triedtodomeache no viene', 'NONE', 'N'),
#  ('Que rico es dormir con el sonido de la lluvia', 'P', 'N'),
#  ('Al final el tiempo terminó por darme la razón', 'NONE', 'N'),
#  ('Hasta lo peor de mi, quiere lo mejor para ti', 'NEU', 'N'),
#  ('@guillevaldes como siempre impecable Guille', 'P', 'N'),
#  ('@Lucialacruel en mi casa tampoco JAJAJAJAJA', 'NONE', 'N'),
#  ('@MilesdeMiles_ esto es en serio? Pobrecito!', 'N', 'P'),
#  ('Es criminal que me hagan caminar tanto hoy', 'N', 'P'),
#  ('@gialau04_ ta weno, es que me pongo celosa', 'NEU', 'N'),
#  ('Esperando el metropolitano hace 26 minutos', 'N', 'P'),
#  ('@pattyulloque Feliz y saludable año nuevo', 'NONE', 'P'),
#  ('@EchavarriaNaya y lo bueno que no engordo', 'P', 'N'),
#  ('@esquinabaja LO vi !! lamentable realidad', 'N', 'P'),
#  ('@The_SoulOfLion Hoy no esta juaneco creo', 'NONE', 'N'),
#  ('Espero llegar al work, estoy dms cansada', 'NONE', 'N'),
#  ('Soy una mrd de persona con buenos deseos', 'NEU', 'P'),
#  ('Resaca vete ya Mañana tengo que trabajar', 'NONE', 'N'),
#  ('No soy celosa, sólo marcó mi territorio', 'NEU', 'N'),
#  ('Al final, siempre me quedo sola en casa', 'NONE', 'N'),
#  ('Levántate a hacer pis y de paso háblame', 'NONE', 'N'),
#  ('Adoro su carita cuando me dice hermosa', 'P', 'N'),
#  ('Adiós alcohol fue lindo mientras duro', 'NEU', 'N'),
#  ('@EstefLescano me siento triste amiga', 'NONE', 'N'),
#  ('Ya tengo en mente mi próximo tatuaje', 'NONE', 'N'),
#  ('Cómo es eso que te extraño? Tamaaare', 'N', 'NONE'),
#  ('Empezando un nuevo viaje #amoviajar', 'NONE', 'P'),
#  ('Que lindo es levantarse sin resaca', 'P', 'N'),
#  ('@sergiocaycho hay que vernos porfa', 'NONE', 'N'),
#  ('@Madrebeagle no todo es perfecto', 'NEU', 'N'),
#  ('@Martinalonsor es que estoy sola', 'NONE', 'N'),
#  ('No me quiero ir bueno sí pero no', 'NEU', 'N'),
#  ('Mañana de nuevo a lo de siempre.', 'NONE', 'N'),
#  ('Es el único trago que tomó puro', 'NONE', 'N'),
#  ('Es tiempo de una nueva aventura', 'NONE', 'N'),
#  ('No fue fácil pero la vida sigue', 'NEU', 'N'),
#  ('@CarlosCook eso es muy peruano', 'NEU', 'N'),
#  ('Desde hoy haré mejor las cosas', 'NONE', 'P'),
#  ('Quiero un perro así porfiii.', 'NONE', 'P'),
#  ('Tengo hambre de algo salado', 'NONE', 'N')]
